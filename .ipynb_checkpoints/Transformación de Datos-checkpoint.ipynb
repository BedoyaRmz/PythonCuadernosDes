# %% [markdown]
# **APRENDIZ:** *Dahiana Bedoya Ramirez*
#
# **FICHA:** *1751400*
#
# **FECHA DE INICIO DEL TALLER:** *8/11/2019*

# %% [markdown]
# ### Selección de datos de tablas

# %%
mail = open('C:\\Users\\02ADSI\\Desktop\\estaciones eolicas\\files\\06\\Estacion1.csv', 'r').readlines()
mail
# Out:
# ['FECHA;HHMMSS;DIR;VEL\n',
#  '16/04/05;11:10:00;135;6,3\n',
#  '16/04/05;11:20:00;135;5,1\n',
#  '16/04/05;11:30:00;135;6,3\n',
#  '16/04/05;11:40:00;113;6,1\n',
#  '16/04/05;11:50:00;135;4,1\n',
#  '16/04/05;12:00:00;135;5,5\n',
#  '16/04/05;12:10:00;135;5,4\n',
#  '16/04/05;12:20:00;135;5,5\n',
#  '16/04/05;12:30:00;90;4,6\n',
#  '16/04/05;12:40:00;90;6,7\n',
#  '16/04/05;12:50:00;90;5,0\n',
#  '16/04/05;13:00:00;90;5,5\n',
#  '16/04/05;13:10:00;135;5,8\n',
#  '16/04/05;13:20:00;135;5,3\n',
#  '16/04/05;13:30:00;135;4,2\n',
#  '16/04/05;13:40:00;135;3,8\n',
#  '16/04/05;13:50:00;135;4,6\n',
#  '16/04/05;14:00:00;113;4,5\n',
#  '16/04/05;14:10:00;135;3,7\n',
#  '16/04/05;14:20:00;203;2,8\n',
#  '16/04/05;14:30:00;113;3,4\n',
#  '16/04/05;14:40:00;135;4,6\n',
#  '16/04/05;14:50:00;135;3,0\n',
#  '16/04/05;15:00:00;180;2,5\n',
#  '16/04/05;15:10:00;113;3,1\n',
#  '16/04/05;15:20:00;135;2,6\n',
#  '16/04/05;15:30:00;135;4,1\n',
#  '16/04/05;15:40:00;135;4,2\n',
# ...

# %%
mail = [row[0:-1] for row in mail]
mail
# Out:
# ['FECHA;HHMMSS;DIR;VEL',
#  '16/04/05;11:10:00;135;6,3',
#  '16/04/05;11:20:00;135;5,1',
#  '16/04/05;11:30:00;135;6,3',
#  '16/04/05;11:40:00;113;6,1',
#  '16/04/05;11:50:00;135;4,1',
#  '16/04/05;12:00:00;135;5,5',
#  '16/04/05;12:10:00;135;5,4',
#  '16/04/05;12:20:00;135;5,5',
#  '16/04/05;12:30:00;90;4,6',
#  '16/04/05;12:40:00;90;6,7',
#  '16/04/05;12:50:00;90;5,0',
#  '16/04/05;13:00:00;90;5,5',
#  '16/04/05;13:10:00;135;5,8',
#  '16/04/05;13:20:00;135;5,3',
#  '16/04/05;13:30:00;135;4,2',
#  '16/04/05;13:40:00;135;3,8',
#  '16/04/05;13:50:00;135;4,6',
#  '16/04/05;14:00:00;113;4,5',
#  '16/04/05;14:10:00;135;3,7',
#  '16/04/05;14:20:00;203;2,8',
#  '16/04/05;14:30:00;113;3,4',
#  '16/04/05;14:40:00;135;4,6',
#  '16/04/05;14:50:00;135;3,0',
#  '16/04/05;15:00:00;180;2,5',
#  '16/04/05;15:10:00;113;3,1',
#  '16/04/05;15:20:00;135;2,6',
#  '16/04/05;15:30:00;135;4,1',
#  '16/04/05;15:40:00;135;4,2',
#  '16/04/05;15:50:00;135;4,3',
#  '16/04/05;16:00:00;135;3,3',
# ...

# %%
mail = [row.split(';') for row in mail]
mail
# Out:
# [['FECHA', 'HHMMSS', 'DIR', 'VEL'],
#  ['16/04/05', '11:10:00', '135', '6,3'],
#  ['16/04/05', '11:20:00', '135', '5,1'],
#  ['16/04/05', '11:30:00', '135', '6,3'],
#  ['16/04/05', '11:40:00', '113', '6,1'],
#  ['16/04/05', '11:50:00', '135', '4,1'],
#  ['16/04/05', '12:00:00', '135', '5,5'],
#  ['16/04/05', '12:10:00', '135', '5,4'],
#  ['16/04/05', '12:20:00', '135', '5,5'],
#  ['16/04/05', '12:30:00', '90', '4,6'],
#  ['16/04/05', '12:40:00', '90', '6,7'],
#  ['16/04/05', '12:50:00', '90', '5,0'],
#  ['16/04/05', '13:00:00', '90', '5,5'],
#  ['16/04/05', '13:10:00', '135', '5,8'],
#  ['16/04/05', '13:20:00', '135', '5,3'],
#  ['16/04/05', '13:30:00', '135', '4,2'],
#  ['16/04/05', '13:40:00', '135', '3,8'],
#  ['16/04/05', '13:50:00', '135', '4,6'],
#  ['16/04/05', '14:00:00', '113', '4,5'],
#  ['16/04/05', '14:10:00', '135', '3,7'],
#  ['16/04/05', '14:20:00', '203', '2,8'],
#  ['16/04/05', '14:30:00', '113', '3,4'],
#  ['16/04/05', '14:40:00', '135', '4,6'],
# ...

# %%
mail = mail[1:]

# %% [markdown]
# Selección de columnas

# %%
[[row[0], row[3], row[2], row[1]] for row in mail]
# Out:
# [['16/04/05', '6,3', '135', '11:10:00'],
#  ['16/04/05', '5,1', '135', '11:20:00'],
#  ['16/04/05', '6,3', '135', '11:30:00'],
#  ['16/04/05', '6,1', '113', '11:40:00'],
#  ['16/04/05', '4,1', '135', '11:50:00'],
#  ['16/04/05', '5,5', '135', '12:00:00'],
#  ['16/04/05', '5,4', '135', '12:10:00'],
#  ['16/04/05', '5,5', '135', '12:20:00'],
#  ['16/04/05', '4,6', '90', '12:30:00'],
#  ['16/04/05', '6,7', '90', '12:40:00'],
#  ['16/04/05', '5,0', '90', '12:50:00'],
#  ['16/04/05', '5,5', '90', '13:00:00'],
#  ['16/04/05', '5,8', '135', '13:10:00'],
#  ['16/04/05', '5,3', '135', '13:20:00'],
#  ['16/04/05', '4,2', '135', '13:30:00'],
#  ['16/04/05', '3,8', '135', '13:40:00'],
#  ['16/04/05', '4,6', '135', '13:50:00'],
#  ['16/04/05', '4,5', '113', '14:00:00'],
#  ['16/04/05', '3,7', '135', '14:10:00'],
#  ['16/04/05', '2,8', '203', '14:20:00'],
#  ['16/04/05', '3,4', '113', '14:30:00'],
#  ['16/04/05', '4,6', '135', '14:40:00'],
#  ['16/04/05', '3,0', '135', '14:50:00'],
# ...

# %% [markdown]
# ### Selección de filas

# %%
[[row[0],row[2], row[1]] for row in mail if row[2] == '90']
# Out:
# [['16/04/05', '90', '12:30:00'],
#  ['16/04/05', '90', '12:40:00'],
#  ['16/04/05', '90', '12:50:00'],
#  ['16/04/05', '90', '13:00:00'],
#  ['16/04/05', '90', '19:40:00'],
#  ['16/04/05', '90', '22:50:00'],
#  ['17/04/05', '90', '0:40:00'],
#  ['17/04/05', '90', '0:50:00'],
#  ['17/04/05', '90', '1:00:00'],
#  ['17/04/05', '90', '1:10:00'],
#  ['17/04/05', '90', '2:20:00'],
#  ['17/04/05', '90', '3:40:00'],
#  ['17/04/05', '90', '4:30:00'],
#  ['17/04/05', '90', '5:00:00'],
#  ['17/04/05', '90', '5:10:00'],
#  ['17/04/05', '90', '5:20:00'],
#  ['17/04/05', '90', '5:50:00'],
#  ['17/04/05', '90', '8:30:00'],
#  ['17/04/05', '90', '9:20:00'],
#  ['17/04/05', '90', '13:40:00'],
#  ['17/04/05', '90', '15:00:00'],
#  ['17/04/05', '90', '15:20:00'],
#  ['17/04/05', '90', '15:30:00'],
#  ['17/04/05', '90', '15:40:00'],
#  ['17/04/05', '90', '19:20:00'],
#  ['17/04/05', '90', '19:40:00'],
#  ['17/04/05', '90', '22:00:00'],
#  ['18/04/05', '90', '0:20:00'],
#  ['18/04/05', '90', '0:40:00'],
# ...

# %%
import re
[[row[0],row[1], row[2]] for row in mail if re.search('^1', row[2])]
# Out:
# [['16/04/05', '11:10:00', '135'],
#  ['16/04/05', '11:20:00', '135'],
#  ['16/04/05', '11:30:00', '135'],
#  ['16/04/05', '11:40:00', '113'],
#  ['16/04/05', '11:50:00', '135'],
#  ['16/04/05', '12:00:00', '135'],
#  ['16/04/05', '12:10:00', '135'],
#  ['16/04/05', '12:20:00', '135'],
#  ['16/04/05', '13:10:00', '135'],
#  ['16/04/05', '13:20:00', '135'],
#  ['16/04/05', '13:30:00', '135'],
#  ['16/04/05', '13:40:00', '135'],
#  ['16/04/05', '13:50:00', '135'],
#  ['16/04/05', '14:00:00', '113'],
#  ['16/04/05', '14:10:00', '135'],
#  ['16/04/05', '14:30:00', '113'],
#  ['16/04/05', '14:40:00', '135'],
#  ['16/04/05', '14:50:00', '135'],
#  ['16/04/05', '15:00:00', '180'],
#  ['16/04/05', '15:10:00', '113'],
#  ['16/04/05', '15:20:00', '135'],
#  ['16/04/05', '15:30:00', '135'],
#  ['16/04/05', '15:40:00', '135'],
#  ['16/04/05', '15:50:00', '135'],
#  ['16/04/05', '16:00:00', '135'],
#  ['16/04/05', '16:10:00', '135'],
#  ['16/04/05', '16:20:00', '135'],
# ...

# %%
[[row[0],row[1], row[2],row[3]] for row in mail if row[1] == '16' and row[3] == '135']
# Out:
# []

# %% [markdown]
# ### Combinación de Columnas

# %%
[[row[0] +' '+ row[1], row[2],row[3]] for row in mail]
# Out:
# [['16/04/05 11:10:00', '135', '6,3'],
#  ['16/04/05 11:20:00', '135', '5,1'],
#  ['16/04/05 11:30:00', '135', '6,3'],
#  ['16/04/05 11:40:00', '113', '6,1'],
#  ['16/04/05 11:50:00', '135', '4,1'],
#  ['16/04/05 12:00:00', '135', '5,5'],
#  ['16/04/05 12:10:00', '135', '5,4'],
#  ['16/04/05 12:20:00', '135', '5,5'],
#  ['16/04/05 12:30:00', '90', '4,6'],
#  ['16/04/05 12:40:00', '90', '6,7'],
#  ['16/04/05 12:50:00', '90', '5,0'],
#  ['16/04/05 13:00:00', '90', '5,5'],
#  ['16/04/05 13:10:00', '135', '5,8'],
#  ['16/04/05 13:20:00', '135', '5,3'],
#  ['16/04/05 13:30:00', '135', '4,2'],
#  ['16/04/05 13:40:00', '135', '3,8'],
#  ['16/04/05 13:50:00', '135', '4,6'],
#  ['16/04/05 14:00:00', '113', '4,5'],
#  ['16/04/05 14:10:00', '135', '3,7'],
#  ['16/04/05 14:20:00', '203', '2,8'],
#  ['16/04/05 14:30:00', '113', '3,4'],
#  ['16/04/05 14:40:00', '135', '4,6'],
#  ['16/04/05 14:50:00', '135', '3,0'],
#  ['16/04/05 15:00:00', '180', '2,5'],
#  ['16/04/05 15:10:00', '113', '3,1'],
# ...

# %% [markdown]
# ### Selección condicional

# %%
[row for row in mail if float(row[2]) > 315]
# Out:
# [['20/04/05', '10:20:00', '338', '3,9'],
#  ['20/04/05', '10:30:00', '338', '2,9'],
#  ['20/04/05', '15:20:00', '338', '2,2'],
#  ['20/04/05', '16:00:00', '338', '3,3'],
#  ['20/04/05', '16:30:00', '338', '4,0'],
#  ['21/04/05', '20:00:00', '338', '1,3'],
#  ['22/04/05', '7:00:00', '338', '0,6'],
#  ['22/04/05', '7:10:00', '338', '0,8'],
#  ['22/04/05', '9:50:00', '338', '3,3'],
#  ['22/04/05', '10:00:00', '338', '3,7'],
#  ['22/04/05', '14:30:00', '338', '2,3'],
#  ['22/04/05', '14:50:00', '338', '1,9'],
#  ['22/04/05', '16:30:00', '338', '3,3'],
#  ['22/04/05', '16:50:00', '338', '2,7'],
#  ['22/04/05', '17:10:00', '338', '1,3'],
#  ['22/04/05', '23:40:00', '338', '1,8'],
#  ['22/04/05', '23:50:00', '338', '1,8'],
#  ['23/04/05', '1:00:00', '338', '1,6'],
#  ['23/04/05', '2:50:00', '338', '1,1'],
#  ['23/04/05', '4:40:00', '338', '1,0'],
#  ['23/04/05', '9:10:00', '338', '1,8'],
#  ['23/04/05', '9:20:00', '338', '1,3'],
#  ['23/04/05', '15:30:00', '338', '3,5'],
# ...

# %% [markdown]
# ### Remoción de duplicados

# %%
[row[1] for row in mail]
# Out:
# ['11:10:00',
#  '11:20:00',
#  '11:30:00',
#  '11:40:00',
#  '11:50:00',
#  '12:00:00',
#  '12:10:00',
#  '12:20:00',
#  '12:30:00',
#  '12:40:00',
#  '12:50:00',
#  '13:00:00',
#  '13:10:00',
#  '13:20:00',
#  '13:30:00',
#  '13:40:00',
#  '13:50:00',
#  '14:00:00',
#  '14:10:00',
#  '14:20:00',
#  '14:30:00',
#  '14:40:00',
#  '14:50:00',
#  '15:00:00',
#  '15:10:00',
#  '15:20:00',
#  '15:30:00',
#  '15:40:00',
#  '15:50:00',
#  '16:00:00',
#  '16:10:00',
#  '16:20:00',
#  '16:30:00',
#  '16:40:00',
#  '16:50:00',
#  '17:00:00',
#  '17:10:00',
#  '17:20:00',
#  '17:30:00',
#  '17:40:00',
#  '17:50:00',
#  '18:00:00',
#  '18:10:00',
#  '18:20:00',
#  '18:30:00',
#  '18:40:00',
#  '18:50:00',
#  '19:00:00',
#  '19:10:00',
#  '19:20:00',
#  '19:30:00',
#  '19:40:00',
#  '19:50:00',
#  '20:00:00',
#  '20:10:00',
#  '20:20:00',
#  '20:30:00',
#  '20:40:00',
#  '20:50:00',
#  '21:00:00',
#  '21:10:00',
#  '21:20:00',
#  '21:30:00',
#  '21:40:00',
#  '21:50:00',
#  '22:00:00',
# ...

# %%
set([row[1] for row in mail])
# Out:
# {'0:00:00',
#  '0:10:00',
#  '0:20:00',
#  '0:30:00',
#  '0:40:00',
#  '0:50:00',
#  '10:00:00',
#  '10:10:00',
#  '10:20:00',
#  '10:30:00',
#  '10:40:00',
#  '10:50:00',
#  '11:00:00',
#  '11:10:00',
#  '11:20:00',
#  '11:30:00',
#  '11:40:00',
#  '11:50:00',
#  '12:00:00',
#  '12:10:00',
#  '12:20:00',
#  '12:30:00',
#  '12:40:00',
#  '12:50:00',
#  '13:00:00',
#  '13:10:00',
#  '13:20:00',
#  '13:30:00',
#  '13:40:00',
#  '13:50:00',
#  '14:00:00',
#  '14:10:00',
#  '14:20:00',
#  '14:30:00',
#  '14:40:00',
#  '14:50:00',
#  '15:00:00',
#  '15:10:00',
#  '15:20:00',
#  '15:30:00',
#  '15:40:00',
#  '15:50:00',
#  '16:00:00',
#  '16:10:00',
#  '16:20:00',
#  '16:30:00',
#  '16:40:00',
#  '16:50:00',
#  '17:00:00',
#  '17:10:00',
#  '17:20:00',
#  '17:30:00',
#  '17:40:00',
#  '17:50:00',
#  '18:00:00',
#  '18:10:00',
#  '18:20:00',
#  '18:30:00',
#  '18:40:00',
#  '18:50:00',
#  '19:00:00',
#  '19:10:00',
#  '19:20:00',
#  '19:30:00',
#  '19:40:00',
#  '19:50:00',
#  '1:00:00',
# ...

# %%
len(set([row[1] for row in mail]))
# Out:
# 144

# %% [markdown]
# ### MANEJO NULL

# %%
taxpayer = open('C:\\Users\\02ADSI\\Desktop\\estaciones eolicas\\files\\06\\Estacion1.csv', 'r').readlines()
taxpayer = [row[0:-1] for row in taxpayer]
taxpayer = [row.split(';') for row in taxpayer]
taxpayer
# Out:
# [['FECHA', 'HHMMSS', 'DIR', 'VEL'],
#  ['16/04/05', '11:10:00', '135', '6,3'],
#  ['16/04/05', '11:20:00', '135', '5,1'],
#  ['16/04/05', '11:30:00', '135', '6,3'],
#  ['16/04/05', '11:40:00', '113', '6,1'],
#  ['16/04/05', '11:50:00', '135', '4,1'],
#  ['16/04/05', '12:00:00', '135', '5,5'],
#  ['16/04/05', '12:10:00', '135', '5,4'],
#  ['16/04/05', '12:20:00', '135', '5,5'],
#  ['16/04/05', '12:30:00', '90', '4,6'],
#  ['16/04/05', '12:40:00', '90', '6,7'],
#  ['16/04/05', '12:50:00', '90', '5,0'],
#  ['16/04/05', '13:00:00', '90', '5,5'],
#  ['16/04/05', '13:10:00', '135', '5,8'],
#  ['16/04/05', '13:20:00', '135', '5,3'],
#  ['16/04/05', '13:30:00', '135', '4,2'],
#  ['16/04/05', '13:40:00', '135', '3,8'],
#  ['16/04/05', '13:50:00', '135', '4,6'],
#  ['16/04/05', '14:00:00', '113', '4,5'],
#  ['16/04/05', '14:10:00', '135', '3,7'],
#  ['16/04/05', '14:20:00', '203', '2,8'],
#  ['16/04/05', '14:30:00', '113', '3,4'],
#  ['16/04/05', '14:40:00', '135', '4,6'],
# ...

# %%
taxpayer = [ [element if element != 'NULL' else None for element in row] for row in taxpayer]
taxpayer
# Out:
# [['FECHA', 'HHMMSS', 'DIR', 'VEL'],
#  ['16/04/05', '11:10:00', '135', '6,3'],
#  ['16/04/05', '11:20:00', '135', '5,1'],
#  ['16/04/05', '11:30:00', '135', '6,3'],
#  ['16/04/05', '11:40:00', '113', '6,1'],
#  ['16/04/05', '11:50:00', '135', '4,1'],
#  ['16/04/05', '12:00:00', '135', '5,5'],
#  ['16/04/05', '12:10:00', '135', '5,4'],
#  ['16/04/05', '12:20:00', '135', '5,5'],
#  ['16/04/05', '12:30:00', '90', '4,6'],
#  ['16/04/05', '12:40:00', '90', '6,7'],
#  ['16/04/05', '12:50:00', '90', '5,0'],
#  ['16/04/05', '13:00:00', '90', '5,5'],
#  ['16/04/05', '13:10:00', '135', '5,8'],
#  ['16/04/05', '13:20:00', '135', '5,3'],
#  ['16/04/05', '13:30:00', '135', '4,2'],
#  ['16/04/05', '13:40:00', '135', '3,8'],
#  ['16/04/05', '13:50:00', '135', '4,6'],
#  ['16/04/05', '14:00:00', '113', '4,5'],
#  ['16/04/05', '14:10:00', '135', '3,7'],
#  ['16/04/05', '14:20:00', '203', '2,8'],
#  ['16/04/05', '14:30:00', '113', '3,4'],
#  ['16/04/05', '14:40:00', '135', '4,6'],
# ...

# %%
[row for row in taxpayer if row[1] is not None]
# Out:
# [['FECHA', 'HHMMSS', 'DIR', 'VEL'],
#  ['16/04/05', '11:10:00', '135', '6,3'],
#  ['16/04/05', '11:20:00', '135', '5,1'],
#  ['16/04/05', '11:30:00', '135', '6,3'],
#  ['16/04/05', '11:40:00', '113', '6,1'],
#  ['16/04/05', '11:50:00', '135', '4,1'],
#  ['16/04/05', '12:00:00', '135', '5,5'],
#  ['16/04/05', '12:10:00', '135', '5,4'],
#  ['16/04/05', '12:20:00', '135', '5,5'],
#  ['16/04/05', '12:30:00', '90', '4,6'],
#  ['16/04/05', '12:40:00', '90', '6,7'],
#  ['16/04/05', '12:50:00', '90', '5,0'],
#  ['16/04/05', '13:00:00', '90', '5,5'],
#  ['16/04/05', '13:10:00', '135', '5,8'],
#  ['16/04/05', '13:20:00', '135', '5,3'],
#  ['16/04/05', '13:30:00', '135', '4,2'],
#  ['16/04/05', '13:40:00', '135', '3,8'],
#  ['16/04/05', '13:50:00', '135', '4,6'],
#  ['16/04/05', '14:00:00', '113', '4,5'],
#  ['16/04/05', '14:10:00', '135', '3,7'],
#  ['16/04/05', '14:20:00', '203', '2,8'],
#  ['16/04/05', '14:30:00', '113', '3,4'],
#  ['16/04/05', '14:40:00', '135', '4,6'],
# ...

# %% [markdown]
# ### Ordenamiento

# %%
from operator import itemgetter
sorted([row for row in mail if int(row[2]) > 200], key=itemgetter(2))
# Out:
# [['24/08/12', '8:10:00', '201', '1,6'],
#  ['21/09/12', '14:40:00', '201', '7,0'],
#  ['27/09/12', '7:30:00', '201', '2,3'],
#  ['5/10/12', '11:50:00', '201', '1,1'],
#  ['12/10/12', '17:20:00', '201', '0,6'],
#  ['15/10/12', '11:20:00', '201', '2,1'],
#  ['15/10/12', '14:00:00', '201', '4,4'],
#  ['16/10/12', '11:00:00', '201', '0,8'],
#  ['21/10/12', '9:30:00', '201', '1,7'],
#  ['9/11/12', '0:30:00', '201', '0,6'],
#  ['12/11/12', '6:30:00', '201', '1,3'],
#  ['11/12/12', '7:50:00', '201', '2,2'],
#  ['14/12/12', '9:10:00', '201', '2,3'],
#  ['14/12/12', '12:20:00', '201', '3,0'],
#  ['15/12/12', '14:50:00', '201', '3,6'],
#  ['16/12/12', '9:20:00', '201', '2,1'],
#  ['25/01/13', '8:40:00', '201', '1,6'],
#  ['27/01/13', '8:30:00', '201', '1,0'],
#  ['4/02/13', '9:10:00', '201', '1,9'],
#  ['2/03/13', '21:10:00', '201', '1,5'],
#  ['12/03/13', '5:40:00', '201', '1,5'],
#  ['29/03/13', '12:40:00', '201', '1,6'],
#  ['5/04/13', '11:50:00', '201', '7,1'],
# ...

# %%
mail = [[element if index != 2 else int(element) for index, element in enumerate(row)] for row in mail]
mail
# Out:
# [['16/04/05', '11:10:00', 135, '6,3'],
#  ['16/04/05', '11:20:00', 135, '5,1'],
#  ['16/04/05', '11:30:00', 135, '6,3'],
#  ['16/04/05', '11:40:00', 113, '6,1'],
#  ['16/04/05', '11:50:00', 135, '4,1'],
#  ['16/04/05', '12:00:00', 135, '5,5'],
#  ['16/04/05', '12:10:00', 135, '5,4'],
#  ['16/04/05', '12:20:00', 135, '5,5'],
#  ['16/04/05', '12:30:00', 90, '4,6'],
#  ['16/04/05', '12:40:00', 90, '6,7'],
#  ['16/04/05', '12:50:00', 90, '5,0'],
#  ['16/04/05', '13:00:00', 90, '5,5'],
#  ['16/04/05', '13:10:00', 135, '5,8'],
#  ['16/04/05', '13:20:00', 135, '5,3'],
#  ['16/04/05', '13:30:00', 135, '4,2'],
#  ['16/04/05', '13:40:00', 135, '3,8'],
#  ['16/04/05', '13:50:00', 135, '4,6'],
#  ['16/04/05', '14:00:00', 113, '4,5'],
#  ['16/04/05', '14:10:00', 135, '3,7'],
#  ['16/04/05', '14:20:00', 203, '2,8'],
#  ['16/04/05', '14:30:00', 113, '3,4'],
#  ['16/04/05', '14:40:00', 135, '4,6'],
#  ['16/04/05', '14:50:00', 135, '3,0'],
#  ['16/04/05', '15:00:00', 180, '2,5'],
# ...

# %%
sorted([row for row in mail if int(row[2]) > 350], key=itemgetter(3))
# Out:
# [['30/06/13', '7:00:00', 358, '0,2'],
#  ['5/08/13', '3:50:00', 355, '0,2'],
#  ['5/04/16', '1:00:00', 354, '0,2'],
#  ['1/03/14', '7:30:00', 353, '0,3'],
#  ['4/03/14', '18:40:00', 354, '0,3'],
#  ['9/10/14', '7:10:00', 360, '0,3'],
#  ['27/10/14', '6:30:00', 352, '0,3'],
#  ['7/11/14', '6:50:00', 352, '0,3'],
#  ['3/03/15', '1:00:00', 357, '0,3'],
#  ['17/09/15', '3:30:00', 351, '0,3'],
#  ['4/04/16', '3:00:00', 358, '0,3'],
#  ['30/11/12', '21:00:00', 358, '0,4'],
#  ['10/02/13', '15:10:00', 354, '0,4'],
#  ['12/02/13', '4:20:00', 355, '0,4'],
#  ['13/02/13', '23:20:00', 359, '0,4'],
#  ['11/04/13', '22:30:00', 353, '0,4'],
#  ['1/05/13', '6:40:00', 351, '0,4'],
#  ['27/09/13', '6:40:00', 355, '0,4'],
#  ['18/11/13', '6:00:00', 354, '0,4'],
#  ['5/12/13', '3:30:00', 356, '0,4'],
#  ['17/12/13', '22:00:00', 359, '0,4'],
#  ['22/12/13', '1:10:00', 357, '0,4'],
#  ['5/10/14', '7:40:00', 355, '0,4'],
#  ['21/11/14', '7:40:00', 352, '0,4'],
#  ['22/01/15', '6:40:00', 351, '0,4'],
# ...

# %%
sorted([row for row in mail], key=itemgetter(1,3))
# Out:
# [['14/02/14', '0:00:00', 162, '0,0'],
#  ['16/07/10', '0:00:00', 0, '0,1'],
#  ['12/07/05', '0:00:00', 0, '0,3'],
#  ['24/03/06', '0:00:00', 135, '0,3'],
#  ['31/05/06', '0:00:00', 90, '0,3'],
#  ['28/01/12', '0:00:00', 113, '0,3'],
#  ['21/03/13', '0:00:00', 4, '0,3'],
#  ['1/11/16', '0:00:00', 72, '0,3'],
#  ['19/09/05', '0:00:00', 0, '0,4'],
#  ['6/04/06', '0:00:00', 113, '0,4'],
#  ['16/08/08', '0:00:00', 225, '0,4'],
#  ['2/04/09', '0:00:00', 68, '0,4'],
#  ['5/05/09', '0:00:00', 45, '0,4'],
#  ['4/11/09', '0:00:00', 158, '0,4'],
#  ['25/05/10', '0:00:00', 135, '0,4'],
#  ['10/04/11', '0:00:00', 315, '0,4'],
#  ['17/11/11', '0:00:00', 0, '0,4'],
#  ['24/01/12', '0:00:00', 68, '0,4'],
#  ['9/10/14', '0:00:00', 299, '0,4'],
#  ['31/03/15', '0:00:00', 94, '0,4'],
#  ['3/08/15', '0:00:00', 148, '0,4'],
#  ['30/11/05', '0:00:00', 0, '0,5'],
#  ['4/01/06', '0:00:00', 68, '0,5'],
#  ['2/05/06', '0:00:00', 0, '0,5'],
#  ['5/12/06', '0:00:00', 0, '0,5'],
# ...

# %% [markdown]
# ### Join

# %%
profile_contact = open('C:\\Users\\02ADSI\\Desktop\\estaciones eolicas\\files\\06\\Estacion1.csv', 'r').readlines()
profile_contact = profile_contact[1:]
profile_contact = [row[0:-1] for row in profile_contact]
profile_contact = [row.split(';') for row in profile_contact]
profile_contact
# Out:
# [['16/04/05', '11:10:00', '135', '6,3'],
#  ['16/04/05', '11:20:00', '135', '5,1'],
#  ['16/04/05', '11:30:00', '135', '6,3'],
#  ['16/04/05', '11:40:00', '113', '6,1'],
#  ['16/04/05', '11:50:00', '135', '4,1'],
#  ['16/04/05', '12:00:00', '135', '5,5'],
#  ['16/04/05', '12:10:00', '135', '5,4'],
#  ['16/04/05', '12:20:00', '135', '5,5'],
#  ['16/04/05', '12:30:00', '90', '4,6'],
#  ['16/04/05', '12:40:00', '90', '6,7'],
#  ['16/04/05', '12:50:00', '90', '5,0'],
#  ['16/04/05', '13:00:00', '90', '5,5'],
#  ['16/04/05', '13:10:00', '135', '5,8'],
#  ['16/04/05', '13:20:00', '135', '5,3'],
#  ['16/04/05', '13:30:00', '135', '4,2'],
#  ['16/04/05', '13:40:00', '135', '3,8'],
#  ['16/04/05', '13:50:00', '135', '4,6'],
#  ['16/04/05', '14:00:00', '113', '4,5'],
#  ['16/04/05', '14:10:00', '135', '3,7'],
#  ['16/04/05', '14:20:00', '203', '2,8'],
#  ['16/04/05', '14:30:00', '113', '3,4'],
#  ['16/04/05', '14:40:00', '135', '4,6'],
#  ['16/04/05', '14:50:00', '135', '3,0'],
# ...

# %%
profile = open('C:\\Users\\02ADSI\\Desktop\\estaciones eolicas\\files\\06\\Estacion2.csv', 'r').readlines()
profile = profile[1:]
profile = [row[0:-1] for row in profile]
profile = [row.split(';') for row in profile]
profile
# Out:
# [['1/08/14', '21:00:00', '59', '1,2'],
#  ['1/08/14', '21:10:00', '125', '0,5'],
#  ['1/08/14', '21:20:00', '328', '0,5'],
#  ['1/08/14', '21:30:00', '181', '0,6'],
#  ['1/08/14', '21:40:00', '320', '0,8'],
#  ['1/08/14', '21:50:00', '329', '0,7'],
#  ['1/08/14', '22:00:00', '334', '0,3'],
#  ['1/08/14', '22:10:00', '295', '0,7'],
#  ['1/08/14', '22:20:00', '311', '0,6'],
#  ['1/08/14', '22:30:00', '290', '1,0'],
#  ['1/08/14', '22:40:00', '316', '0,5'],
#  ['1/08/14', '22:50:00', '293', '1,0'],
#  ['1/08/14', '23:00:00', '316', '0,5'],
#  ['1/08/14', '23:10:00', '281', '0,6'],
#  ['1/08/14', '23:20:00', '320', '0,5'],
#  ['1/08/14', '23:30:00', '324', '0,7'],
#  ['1/08/14', '23:40:00', '257', '0,9'],
#  ['1/08/14', '23:50:00', '321', '0,4'],
#  ['2/08/14', '00:10:00', '64', '0,6'],
#  ['2/08/14', '00:20:00', '320', '0,7'],
#  ['2/08/14', '00:30:00', '281', '0,8'],
#  ['2/08/14', '00:40:00', '287', '0,7'],
#  ['2/08/14', '00:50:00', '349', '0,6'],
# ...
